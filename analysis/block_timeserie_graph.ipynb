# %%
import pandas as pd

# %%
ts = pd.read_csv("../data/indexed/cronos/blocks/samples/15min.csv", sep=",", names=["block_number", "datetime"])

# %%
ts["datetime"] = pd.to_datetime(ts["datetime"])

# %%
ts.set_index("datetime", inplace=True)

# %%
ts.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>
